# %%
'''
This notebook is used to answer research question 2:
What impact does a difference of beliefs makes (between scenarios 0 and 2) on the policy process
emergence (benchmark scenario) model.
'''
# Out:
# '\nThis notebook is used to answer research question 2:\nWhat impact does a difference of beliefs makes (between scenarios 0 and 2) on the policy process\nemergence (benchmark scenario) model.\n'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import ast
import copy
from copy import deepcopy

# %%
rep_runs = 50 # repetitions
sce = [0, 2]

linestyles = ['-',':', '--','-', ':', '--','-', '--', ':','-', '--', ':','-', '--', ':','-', '--', ':']

# %%
'''
Analysis of the predation model - WITH POLICY EMERGENCE
Main parameters of interest (the rest is constant):
- Wolf count
- Sheep count
- Grass patches count
'''

steps_t = []
sheep_t = []
wolves_t = []
grass_t = []
sheepC_t = []
wolvesC_t = []
grassC_t = []
sheepR_t = []
wolvesR_t = []
grassR_t = []


# going through all of the scenarios
for sce_i in range(len(sce)):
    
    predation_model = []

    steps = []
    sheep = []
    wolves = []
    grass = []
    sheepC = []
    wolvesC = []
    grassC = []
    sheepR = []
    wolvesR = []
    grassR = []

    # We first read all the files into arrays that contains each entire file
    for i in range(rep_runs):
        predation_model.append(pd.read_csv('O_Pre_model_Sce' + str(sce[sce_i]) + '_Run' + str(i) + '_el0.0.csv'))
        
        steps.append([])
        sheep.append([])
        wolves.append([])
        grass.append([])
        sheepC.append([])
        wolvesC.append([])
        grassC.append([])
        sheepR.append([])
        wolvesR.append([])
        grassR.append([])
    
    print('Scenario', str(sce_i), 'files opened')
        
    print(predation_model[0].head())
    print(list(predation_model[0].head(0)))

    # saving the paremeters in different arrays
    for i in range(rep_runs):
        print(i)
        for index, row in predation_model[i].iterrows():
            steps[i].append(index)
            sheep[i].append(row['Sheep'])
            wolves[i].append(row['Wolves'])
            grass[i].append(row['Grass'])
            sheepC[i].append(row['SheepChange'])
            wolvesC[i].append(row['WolfChange'])
            grassC[i].append(row['GrassChange'])
            sheepR[i].append(row['SheepRepro'])
            wolvesR[i].append(row['WolfRepro'])
            grassR[i].append(row['GrassRegrowth'])

    # saving all scenarios into arrays
    steps_t.append(copy.deepcopy(steps))
    sheep_t.append(copy.deepcopy(sheep))
    wolves_t.append(wolves)
    grass_t.append(grass)
    sheepC_t.append(sheepC)
    wolvesC_t.append(wolvesC)
    grassC_t.append(grassC)
    sheepR_t.append(sheepR)
    wolvesR_t.append(wolvesR)
    grassR_t.append(grassR)

print('All files saved')
# Out:
# Scenario 0 files opened
#    Unnamed: 0  Sheep  Wolves  Grass  SheepChange  WolfChange  GrassChange  \
# 0           0     93      49   1217           -7          -1           -9
# 1           1     91      54   1213           -9           4          -13
# 2           2     93      53   1224           -7           3           -2
# 3           3     95      56   1215           -5           6          -11
# 4           4     94      57   1220           -6           7           -6
#
#    SheepRepro  WolfRepro  GrassRegrowth
# 0        0.04       0.05             30
# 1        0.04       0.05             30
# 2        0.04       0.05             30
# 3        0.04       0.05             30
# 4        0.04       0.05             30
# ['Unnamed: 0', 'Sheep', 'Wolves', 'Grass', 'SheepChange', 'WolfChange', 'GrassChange', 'SheepRepro', 'WolfRepro', 'GrassRegrowth']
# Scenario 1 files opened
#    Unnamed: 0  Sheep  Wolves  Grass  SheepChange  WolfChange  GrassChange  \
# ...

# %%
'''
Getting the Kernel Density Estimates for all parameters saved
WITH PE results
'''

sheep_t_KDE_100 = []
wolves_t_KDE_100 = []
grass_t_KDE_100 = []

sheep_t_KDE_600 = []
wolves_t_KDE_600 = []
grass_t_KDE_600 = []

sheep_t_KDE_1100 = []
wolves_t_KDE_1100 = []
grass_t_KDE_1100 = []

sheep_t_KDE_1600 = []
wolves_t_KDE_1600 = []
grass_t_KDE_1600 = []
    
for sce_i in range(len(sce)):
    
    sheep_t_KDE_100.append([])
    wolves_t_KDE_100.append([])
    grass_t_KDE_100.append([])

    sheep_t_KDE_600.append([])
    wolves_t_KDE_600.append([])
    grass_t_KDE_600.append([])

    sheep_t_KDE_1100.append([])
    wolves_t_KDE_1100.append([])
    grass_t_KDE_1100.append([])

    sheep_t_KDE_1600.append([])
    wolves_t_KDE_1600.append([])
    grass_t_KDE_1600.append([])

    # saving/sorting
    for i in range(rep_runs):
        sheep_t_KDE_100[sce_i].append(round(sheep_t[sce_i][i][99],4))
        wolves_t_KDE_100[sce_i].append(round(wolves_t[sce_i][i][99],4))
        grass_t_KDE_100[sce_i].append(round(grass_t[sce_i][i][99],4))

        sheep_t_KDE_600[sce_i].append(round(sheep_t[sce_i][i][599],4))
        wolves_t_KDE_600[sce_i].append(round(wolves_t[sce_i][i][599],4))
        grass_t_KDE_600[sce_i].append(round(grass_t[sce_i][i][599],4))

        sheep_t_KDE_1100[sce_i].append(round(sheep_t[sce_i][i][1099],4))
        wolves_t_KDE_1100[sce_i].append(round(wolves_t[sce_i][i][1099],4))
        grass_t_KDE_1100[sce_i].append(round(grass_t[sce_i][i][1099],4))

        sheep_t_KDE_1600[sce_i].append(round(sheep_t[sce_i][i][-101],4))
        wolves_t_KDE_1600[sce_i].append(round(wolves_t[sce_i][i][-101],4))
        grass_t_KDE_1600[sce_i].append(round(grass_t[sce_i][i][-101],4)) 

    # pdf = kde_funcs(x, evenness_KDE_a, bandwidth=0.2)
    hist = plt.hist(sheep_t_KDE_1600[sce_i], bins=10, density=True, alpha = 0.5, orientation="horizontal")
    hist2 = plt.hist(wolves_t_KDE_1600[sce_i], bins=10, density=True, alpha = 0.5, orientation="horizontal")

# %%
'''
The counts - PLOTTING
SHEEP AND WOLF PER SCENARIO WITH PE
'''

fig = plt.figure(tight_layout=True, figsize=(15,12))
gs = gridspec.GridSpec(4, 8)

'''SHEEP WOLF WITH PE SCENARIO 0'''
# number of agents (sheep)
axarr2 = fig.add_subplot(gs[0, 0:5])
j = 0
axarr2.plot(steps_t[0][i], sheep_t[0][0], color = 'b', label='Sheep')
axarr2.plot(steps_t[0][i], wolves_t[0][0], color = 'r', label='Wolves')
for i in range(rep_runs):
    axarr2.plot(steps_t[j][i], sheep_t[j][i], color = 'b')
    axarr2.plot(steps_t[j][i], wolves_t[j][i], color = 'r')
axarr2.set_title('Sheep/Wolves (Scenario 0)')
axarr2.set_xlim([0, 1600])
axarr2.set_ylim([0, 400])
axarr2.set_ylabel('# of agents')
axarr2.legend
axarr2.legend(loc="upper left")
axarr2.grid(True)

# KDE (sheep/wolf) - 600
axarr2 = fig.add_subplot(gs[0, 5:6])
axarr2.hist(sheep_t_KDE_600[j], bins=10, density=True, orientation="horizontal", color = 'b')
axarr2.hist(wolves_t_KDE_600[j], bins=10, density=True, orientation="horizontal", color = 'r')
axarr2.set_title('t = 600')
axarr2.set_xlim([0, 0.050])
axarr2.set_ylim([0, 400])
axarr2.grid(True)

# KDE (sheep/wolf) - 1100
axarr2 = fig.add_subplot(gs[0, 6:7])
axarr2.hist(sheep_t_KDE_1100[j], bins=10, density=True, orientation="horizontal", color = 'b')
axarr2.hist(wolves_t_KDE_1100[j], bins=10, density=True, orientation="horizontal", color = 'r')
axarr2.set_title('t = 1100')
axarr2.set_xlim([0, 0.050])
axarr2.set_ylim([0, 400])
axarr2.grid(True)

# KDE (sheep/wolf) - 1600
axarr2 = fig.add_subplot(gs[0, 7:8])
axarr2.hist(sheep_t_KDE_1600[j], bins=10, density=True, orientation="horizontal", color = 'b')
axarr2.hist(wolves_t_KDE_1600[j], bins=10, density=True, orientation="horizontal", color = 'r')
axarr2.set_title('t = 1600')
axarr2.set_xlim([0, 0.050])
axarr2.set_ylim([0, 400])
axarr2.grid(True)

'''SHEEP WOLF WITH PE SCENARIO 1'''
# number of agents (sheep/wolf)
axarr2 = fig.add_subplot(gs[1, 0:5])
j = 1
axarr2.plot(steps_t[1][i], sheep_t[1][0], color = 'b', label='Sheep')
axarr2.plot(steps_t[1][i], wolves_t[1][0], color = 'r', label='Wolves')
for i in range(rep_runs):
    axarr2.plot(steps_t[j][i], sheep_t[j][i], color = 'b')
    axarr2.plot(steps_t[j][i], wolves_t[j][i], color = 'r')
axarr2.set_title('Sheep/Wolves (Scenario 2)')
axarr2.set_xlim([0, 1600])
axarr2.set_ylim([0, 400])
axarr2.set_ylabel('# of agents')
axarr2.legend
axarr2.legend(loc="upper left")
axarr2.grid(True)

# KDE (sheep/wolf) - 600
axarr2 = fig.add_subplot(gs[1, 5:6])
axarr2.hist(sheep_t_KDE_600[j], bins=10, density=True, orientation="horizontal", color = 'b')
axarr2.hist(wolves_t_KDE_600[j], bins=10, density=True, orientation="horizontal", color = 'r')
axarr2.set_title('t = 600')
axarr2.set_xlim([0, 0.050])
axarr2.set_ylim([0, 400])
axarr2.grid(True)

# KDE (sheep/wolf) - 1100
axarr2 = fig.add_subplot(gs[1, 6:7])
axarr2.hist(sheep_t_KDE_1100[j], bins=10, density=True, orientation="horizontal", color = 'b')
axarr2.hist(wolves_t_KDE_1100[j], bins=10, density=True, orientation="horizontal", color = 'r')
axarr2.set_title('t = 1100')
axarr2.set_xlim([0, 0.050])
axarr2.set_ylim([0, 400])
axarr2.grid(True)

# KDE (sheep/wolf) - 1600
axarr2 = fig.add_subplot(gs[1, 7:8])
axarr2.hist(sheep_t_KDE_1600[j], bins=10, density=True, orientation="horizontal", color = 'b')
axarr2.hist(wolves_t_KDE_1600[j], bins=10, density=True, orientation="horizontal", color = 'r')
axarr2.set_title('t = 1600')
axarr2.set_xlim([0, 0.050])
axarr2.set_ylim([0, 400])
axarr2.grid(True)

'''SHEEP WOLF WITH PE SCENARIO 0'''
# number of agents (grass)
axarr2 = fig.add_subplot(gs[2, 0:5])
j = 0
axarr2.plot(steps_t[0][i], grass_t[0][0], color = 'g', label='Grass')
for i in range(rep_runs):
    axarr2.plot(steps_t[j][i], grass_t[j][i], color = 'g')
axarr2.set_title('Grass (Scenario 0)')
axarr2.set_xlim([0, 1600])
axarr2.set_ylim([500, 2200])
axarr2.set_ylabel('# of patches')
axarr2.legend
axarr2.legend(loc="upper left")
axarr2.grid(True)

# KDE (grass) - 600
axarr2 = fig.add_subplot(gs[2, 5:6])
axarr2.hist(grass_t_KDE_600[j], bins=10, density=True, orientation="horizontal", color = 'g')
axarr2.set_title('t = 600')
axarr2.set_xlim([0, 0.005])
axarr2.set_ylim([500, 2200])
axarr2.grid(True)

# KDE (grass) - 1100
axarr2 = fig.add_subplot(gs[2, 6:7])
axarr2.hist(grass_t_KDE_1100[j], bins=10, density=True, orientation="horizontal", color = 'g')
axarr2.set_title('t = 1100')
axarr2.set_xlim([0, 0.005])
axarr2.set_ylim([500, 2200])
axarr2.grid(True)

# KDE (grass) - 1600
axarr2 = fig.add_subplot(gs[2, 7:8])
axarr2.hist(grass_t_KDE_1600[j], bins=10, density=True, orientation="horizontal", color = 'g')
axarr2.set_title('t = 1600')
axarr2.set_xlim([0, 0.0050])
axarr2.set_ylim([500, 2200])
axarr2.grid(True)

'''SHEEP WOLF WITH PE SCENARIO 2'''
# number of agents (grass)
axarr2 = fig.add_subplot(gs[3, 0:5])
j = 1
axarr2.plot(steps_t[1][i], grass_t[1][0], color = 'g', label='Grass')
for i in range(rep_runs):
    axarr2.plot(steps_t[j][i], grass_t[j][i], color = 'g')
axarr2.set_title('Grass (Scenario 2)')
axarr2.set_xlim([0, 1600])
axarr2.set_ylim([500, 2200])
axarr2.set_ylabel('# of patches')
axarr2.legend
axarr2.legend(loc="upper left")
axarr2.grid(True)

# KDE (grass) - 600
axarr2 = fig.add_subplot(gs[3, 5:6])
axarr2.hist(grass_t_KDE_600[j], bins=10, density=True, orientation="horizontal", color = 'g')
axarr2.set_title('t = 600')
axarr2.set_xlim([0, 0.005])
axarr2.set_ylim([500, 2200])
axarr2.grid(True)

# KDE (grass) - 1100
axarr2 = fig.add_subplot(gs[3, 6:7])
axarr2.hist(grass_t_KDE_1100[j], bins=10, density=True, orientation="horizontal", color = 'g')
axarr2.set_title('t = 1100')
axarr2.set_xlim([0, 0.005])
axarr2.set_ylim([500, 2200])
axarr2.grid(True)

# KDE (grass) - 1600
axarr2 = fig.add_subplot(gs[3, 7:8])
axarr2.hist(grass_t_KDE_1600[j], bins=10, density=True, orientation="horizontal", color = 'g')
axarr2.set_title('t = 1600')
axarr2.set_xlim([0, 0.0050])
axarr2.set_ylim([500, 2200])
axarr2.grid(True)

fig.savefig('Predation_Q2_pops.eps', format='eps', dpi=1000)

# %%
'''
The counts - PLOTTING
SHEEP AND WOLF AND GRASS CHANGE PER SCENARIO WITH PE
'''

fig = plt.figure(tight_layout=True, figsize=(15,12))
gs = gridspec.GridSpec(4, 8)

'''SHEEP WOLF WITH PE SCENARIO 0'''
# number of agents (sheep)
axarr2 = fig.add_subplot(gs[0, 0:8])
j = 0
axarr2.plot(steps_t[0][i], sheepC_t[0][0], color = 'b', label='Sheep')
axarr2.plot(steps_t[0][i], wolvesC_t[0][0], color = 'r', label='Wolves')
for i in range(rep_runs):
    axarr2.plot(steps_t[j][i], sheepC_t[j][i], color = 'b')
    axarr2.plot(steps_t[j][i], wolvesC_t[j][i], color = 'r')
axarr2.set_title('Sheep/Wolves (Scenario 0)')
axarr2.set_xlim([0, 1600])
axarr2.set_ylim([-200, 200])
axarr2.set_ylabel('# of agents')
axarr2.legend
axarr2.legend(loc="upper left")
axarr2.grid(True)

'''SHEEP WOLF WITH PE SCENARIO 1'''
# number of agents (sheep/wolf)
axarr2 = fig.add_subplot(gs[1, 0:8])
j = 1
axarr2.plot(steps_t[1][i], sheepC_t[1][0], color = 'b', label='Sheep')
axarr2.plot(steps_t[1][i], wolvesC_t[1][0], color = 'r', label='Wolves')
for i in range(rep_runs):
    axarr2.plot(steps_t[j][i], sheepC_t[j][i], color = 'b')
    axarr2.plot(steps_t[j][i], wolvesC_t[j][i], color = 'r')
axarr2.set_title('Sheep/Wolves (Scenario 1)')
axarr2.set_xlim([0, 1600])
axarr2.set_ylim([-200, 200])
axarr2.set_ylabel('# of agents')
axarr2.legend
axarr2.legend(loc="upper left")
axarr2.grid(True)

'''SHEEP WOLF WITH PE SCENARIO 0'''
# number of agents (grass)
axarr2 = fig.add_subplot(gs[2, 0:8])
j = 0
axarr2.plot(steps_t[0][i], grassC_t[0][0], color = 'g', label='Grass')
for i in range(rep_runs):
    axarr2.plot(steps_t[j][i], grassC_t[j][i], color = 'g')
axarr2.set_title('Grass (Scenario 0)')
axarr2.set_xlim([0, 1600])
axarr2.set_ylim([-750, 750])
axarr2.set_ylabel('# of patches')
axarr2.legend
axarr2.legend(loc="upper left")
axarr2.grid(True)

'''SHEEP WOLF WITH PE SCENARIO 2'''
# number of agents (grass)
axarr2 = fig.add_subplot(gs[3, 0:8])
j = 1
axarr2.plot(steps_t[j][i], grassC_t[j][0], color = 'g', label='Grass')
for i in range(rep_runs):
    axarr2.plot(steps_t[j][i], grassC_t[j][i], color = 'g')
axarr2.set_title('Grass (Scenario 1)')
axarr2.set_xlim([0, 1600])
axarr2.set_ylim([-750, 750])
axarr2.set_ylabel('# of patches')
axarr2.legend
axarr2.legend(loc="upper left")
axarr2.grid(True)

# fig.savefig('Predation_Q1_pops.eps', format='eps', dpi=1000)
